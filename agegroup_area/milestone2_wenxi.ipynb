# %%
import pandas as pd
import networkx as nx

# %%
data = pd.read_csv('../la_crime_cleaned.csv')

# Filter out invalid 'victim_sex' values
valid_sexes = {'Male', 'Female'}
# Valid Data
la_crime_sample = data[data['victim_sex'].isin(valid_sexes)]

# Filter out invalid 'victim_age' values
la_crime_sample = la_crime_sample[la_crime_sample['victim_age'] <= 100]

# Categorize 'victim_age' into different age groups
def categorize_age(age):
    if age <= 12:
        return 'Child'
    elif age <= 17:
        return 'Teenager'
    elif age <= 29:
        return 'Young Adult'
    elif age <= 59:
        return 'Adult'
    else:
        return 'Senior'

# Create a new 'age_group' column
la_crime_sample['age_group'] = la_crime_sample['victim_age'].apply(categorize_age)
G = nx.Graph()

# Add nodes and edges
for index, row in la_crime_sample.iterrows():
    age_group_node = f"Age Group {row['age_group']}"
    area_node = f"Area {row['area_name']}"
    G.add_node(age_group_node, type='age_group')
    G.add_node(area_node, type='area')
    G.add_edge(age_group_node, area_node, weight=G.get_edge_data(age_group_node, area_node, default={'weight': 0})['weight'] + 1)

nx.write_gexf(G, 'la_crime_network_age_groups.gexf')

# %%
# Degree Centrality
degree_centrality = nx.degree_centrality(G)
# Sort the nodes by degree centrality
sorted_degree_centrality = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)
for node, centrality in sorted_degree_centrality[:5]:
    print(f"Node: {node}, Degree Centrality: {centrality}")
# Out:
# Node: Age Group Adult, Degree Centrality: 0.84
# Node: Age Group Senior, Degree Centrality: 0.84
# Node: Age Group Young Adult, Degree Centrality: 0.84
# Node: Age Group Child, Degree Centrality: 0.84
# Node: Age Group Teenager, Degree Centrality: 0.84

# %%
# Edge Weights
edge_weights = [(u, v, d['weight']) for u, v, d in G.edges(data=True)]
# Sort the edges by weight
sorted_edge_weights = sorted(edge_weights, key=lambda x: x[2], reverse=True)
for u, v, weight in sorted_edge_weights[:5]:
    print(f"Edge: ({u}, {v}), Weight: {weight}")
# Out:
# Edge: (Age Group Adult, Area 77th Street), Weight: 49644
# Edge: (Age Group Adult, Area Southwest), Weight: 43615
# Edge: (Age Group Adult, Area Pacific), Weight: 40165
# Edge: (Age Group Adult, Area N Hollywood), Weight: 40136
# Edge: (Age Group Adult, Area Topanga), Weight: 37751

# %%
# Sort the areas for each age group with highest edge weights (crime counts)
age_groups = ['Child', 'Teenager', 'Young Adult', 'Adult', 'Senior']
crime_by_area_for_age_group = {age_group: {} for age_group in age_groups}
areas = [node for node, attr in G.nodes(data=True) if attr['type'] == 'area']

# Calculate the crime count for each area for each age group
for area in areas:
    for age_node in G.neighbors(area):
        age_group = age_node.split()[-1]
        if age_group in age_groups:
            crime_count = G[area][age_node]['weight']
            if area in crime_by_area_for_age_group[age_group]:
                crime_by_area_for_age_group[age_group][area] += crime_count
            else:
                crime_by_area_for_age_group[age_group][area] = crime_count

# Sort the areas for each age group by crime count
sorted_areas_by_age_group = {}
for age_group in age_groups:
    sorted_areas = sorted(crime_by_area_for_age_group[age_group].items(), key=lambda x: x[1], reverse=True)
    sorted_areas_by_age_group[age_group] = sorted_areas

print(sorted_areas_by_age_group)
# Out:
# {'Child': [('Area N Hollywood', 3229), ('Area Harbor', 2156), ('Area 77th Street', 2032), ('Area Mission', 1927), ('Area Newton', 1646), ('Area Rampart', 1641), ('Area Southwest', 1562), ('Area Devonshire', 1452), ('Area Southeast', 1095), ('Area Hollenbeck', 918), ('Area Wilshire', 742), ('Area Foothill', 703), ('Area Olympic', 662), ('Area Van Nuys', 611), ('Area Northeast', 498), ('Area Topanga', 475), ('Area Pacific', 437), ('Area West Valley', 423), ('Area Central', 407), ('Area Hollywood', 350), ('Area West LA', 247)], 'Teenager': [('Area 77th Street', 6367), ('Area N Hollywood', 5787), ('Area Southwest', 4722), ('Area Mission', 4678), ('Area Southeast', 4633), ('Area Newton', 4375), ('Area Harbor', 4038), ('Area Rampart', 3494), ('Area Hollenbeck', 2890), ('Area Wilshire', 2760), ('Area Foothill', 2556), ('Area Northeast', 2411), ('Area Devonshire', 2388), ('Area Olympic', 2215), ('Area Topanga', 2143), ('Area Van Nuys', 2130), ('Area West Valley', 1790), ('Area Pacific', 1642), ('Area West LA', 1552), ('Area Hollywood', 1323), ('Area Central', 1107)], 'Young Adult': [], 'Adult': [('Area 77th Street', 78035), ('Area Southwest', 75304), ('Area N Hollywood', 60185), ('Area Southeast', 59454), ('Area Pacific', 57268), ('Area Topanga', 54779), ('Area Mission', 53422), ('Area Van Nuys', 53406), ('Area Central', 52951), ('Area Hollywood', 52777), ('Area Northeast', 50873), ('Area Devonshire', 48846), ('Area Rampart', 48270), ('Area Newton', 47728), ('Area Olympic', 47641), ('Area West LA', 46058), ('Area Wilshire', 45557), ('Area West Valley', 44578), ('Area Harbor', 44264), ('Area Foothill', 40562), ('Area Hollenbeck', 34644)], 'Senior': [('Area West LA', 9756), ('Area Devonshire', 9394), ('Area 77th Street', 8561), ('Area Southwest', 8521), ('Area Topanga', 8335), ('Area Pacific', 8220), ('Area West Valley', 8138), ('Area N Hollywood', 7590), ('Area Northeast', 7188), ('Area Van Nuys', 6851), ('Area Harbor', 6667), ('Area Wilshire', 6317), ('Area Mission', 5690), ('Area Southeast', 5463), ('Area Olympic', 5248), ('Area Foothill', 5209), ('Area Central', 5068), ('Area Hollywood', 4514), ('Area Rampart', 4462), ('Area Hollenbeck', 3886), ('Area Newton', 3638)]}

# %%
# Visualize it with folium
import folium

data =  la_crime_sample

# Generate a DataFrame with the top 20 areas by crime count
crime_counts = data.groupby('area_name').agg({
    'ID': 'count',
    'longitude': 'first', 
    'latitude': 'first',
    'age_group': lambda x: x.mode()[0],
    'victim_sex': lambda x: x.mode()[0]
})
crime_counts = crime_counts.sort_values('ID', ascending=False).head(20)
# Generate Map with coordinates for Los Angeles
m = folium.Map(location=[34.0522, -118.2437], zoom_start=10)  

# Draw circles for each area (colored by most common victim sex)
for index, row in crime_counts.iterrows():
    circle_color = 'red' if row['victim_sex'] == 'Female' else 'blue'
    folium.Circle(
        location=[row['longitude'], row['latitude']],
        radius=row['ID'] * 0.02, 
        color=circle_color,
        fill=True,
        fill_color=circle_color,
        fill_opacity=0.5,
        popup=f"Area: {index}<br>Most common age group: {row['age_group']}<br>Most common gender: {row['victim_sex']}<br>Incidents: {row['ID']}"
    ).add_to(m)

m.save('LA_Crime_Map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4225e7742c56714b77ee522bf0861df0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4225e7742c56714b77ee522bf0861df0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4225e7742c56714b77ee522bf0861df0 = L.map(
#                 &quot;map_4225e7742c56714b77ee522bf0861df0&quot;,
#                 {
#                     center: [34.0522, -118.2437],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce1ce8b7fc9a5f555ff28ac861177398 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_ce1ce8b7fc9a5f555ff28ac861177398.addTo(map_4225e7742c56714b77ee522bf0861df0);
#
#             var circle_3f322959f54881c8a3fed39411de88c8 = L.circle(
#                 [33.9829, -118.3338],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1899.9, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4225e7742c56714b77ee522bf0861df0);
#
#
#         var popup_5a94c1d4fa9e58ca3b137456c3f0e38b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_68f23513a2c3ea37f7acc1a929fa2de3 = $(`&lt;div id=&quot;html_68f23513a2c3ea37f7acc1a929fa2de3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Area: 77th Street&lt;br&gt;Most common age group: Adult&lt;br&gt;Most common gender: Female&lt;br&gt;Incidents: 94995&lt;/div&gt;`)[0];
#                 popup_5a94c1d4fa9e58ca3b137456c3f0e38b.setContent(html_68f23513a2c3ea37f7acc1a929fa2de3);
#
#
#
#         circle_3f322959f54881c8a3fed39411de88c8.bindPopup(popup_5a94c1d4fa9e58ca3b137456c3f0e38b)
#         ;
#
#
#
#
#             var circle_6fe8475209f8be831a701e682657500a = L.circle(
#                 [34.0037, -118.3045],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1802.18, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4225e7742c56714b77ee522bf0861df0);
#
#
#         var popup_9b11094a29c806c8301add0570db4751 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b0753575c7c6d04850b552f239fc8db = $(`&lt;div id=&quot;html_3b0753575c7c6d04850b552f239fc8db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Area: Southwest&lt;br&gt;Most common age group: Adult&lt;br&gt;Most common gender: Female&lt;br&gt;Incidents: 90109&lt;/div&gt;`)[0];
#                 popup_9b11094a29c806c8301add0570db4751.setContent(html_3b0753575c7c6d04850b552f239fc8db);
#
#
#
#         circle_6fe8475209f8be831a701e682657500a.bindPopup(popup_9b11094a29c806c8301add0570db4751)
#         ;
#
#
#
#
#             var circle_0a392b34977bf708f9f5d59263739d78 = L.circle(
#                 [34.2012, -118.416],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1535.82, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4225e7742c56714b77ee522bf0861df0);
#
#
#         var popup_a195312d42fa5a3a51506c96851e9c0c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ef01b59df7196397afc3cc198062cb4 = $(`&lt;div id=&quot;html_9ef01b59df7196397afc3cc198062cb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Area: N Hollywood&lt;br&gt;Most common age group: Adult&lt;br&gt;Most common gender: Male&lt;br&gt;Incidents: 76791&lt;/div&gt;`)[0];
#                 popup_a195312d42fa5a3a51506c96851e9c0c.setContent(html_9ef01b59df7196397afc3cc198062cb4);
#
#
#
#         circle_0a392b34977bf708f9f5d59263739d78.bindPopup(popup_a195312d42fa5a3a51506c96851e9c0c)
#         ;

# %%
# Generate a DataFrame with the top 3 areas for each age group
age_group_area_counts = data.groupby(['age_group', 'area_name']).agg({
    'ID': 'count',
    'longitude': 'first', 
    'latitude': 'first'
}).reset_index()
top_3_per_age_group = age_group_area_counts.groupby('age_group').apply(lambda x: x.nlargest(3, 'ID')).reset_index(drop=True)

# Color each area based on age group
age_group_colors = {
    'Child': 'green',
    'Teenager': 'blue',
    'Young Adult': 'orange',
    'Adult': 'red',
    'Senior': 'purple'
}

def get_color(age_group):
    return age_group_colors.get(age_group, 'black')

m = folium.Map(location=[34.0522, -118.2437], zoom_start=10)

# Draw circles for each area (colored by age groups)
for _, row in top_3_per_age_group.iterrows():
    folium.Circle(
        location=[row['longitude'], row['latitude']],
        radius=row['ID'] * 0.08,
        color=get_color(row['age_group']),
        fill=True,
        fill_color=get_color(row['age_group']),
        fill_opacity=0.5,
        popup=f"Area: {row['area_name']}<br>Age Group: {row['age_group']}<br>Incidents: {row['ID']}"
    ).add_to(m)

m.save('LA_Crime_Top_3_Areas_Per_Age_Group_Map.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_debefb064290ff473b0ee74cb95053c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_debefb064290ff473b0ee74cb95053c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_debefb064290ff473b0ee74cb95053c0 = L.map(
#                 &quot;map_debefb064290ff473b0ee74cb95053c0&quot;,
#                 {
#                     center: [34.0522, -118.2437],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d5be69c287f327525a54a0b194f6622 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_5d5be69c287f327525a54a0b194f6622.addTo(map_debefb064290ff473b0ee74cb95053c0);
#
#             var circle_b8536b596bccbd3263ab3f82b1e7e9f2 = L.circle(
#                 [33.9829, -118.3338],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3971.52, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_debefb064290ff473b0ee74cb95053c0);
#
#
#         var popup_22b0af2baba23a741b85787598581676 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6743adce9d56c48bb0cbaf01bd713ac7 = $(`&lt;div id=&quot;html_6743adce9d56c48bb0cbaf01bd713ac7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Area: 77th Street&lt;br&gt;Age Group: Adult&lt;br&gt;Incidents: 49644&lt;/div&gt;`)[0];
#                 popup_22b0af2baba23a741b85787598581676.setContent(html_6743adce9d56c48bb0cbaf01bd713ac7);
#
#
#
#         circle_b8536b596bccbd3263ab3f82b1e7e9f2.bindPopup(popup_22b0af2baba23a741b85787598581676)
#         ;
#
#
#
#
#             var circle_65892d2e73527175c5a8b8070fbf2380 = L.circle(
#                 [34.0037, -118.3045],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3489.2000000000003, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_debefb064290ff473b0ee74cb95053c0);
#
#
#         var popup_19a11ca325f807d39b4719e1a2e7931b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_856118b7fdca0c36263ee0aaa744d904 = $(`&lt;div id=&quot;html_856118b7fdca0c36263ee0aaa744d904&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Area: Southwest&lt;br&gt;Age Group: Adult&lt;br&gt;Incidents: 43615&lt;/div&gt;`)[0];
#                 popup_19a11ca325f807d39b4719e1a2e7931b.setContent(html_856118b7fdca0c36263ee0aaa744d904);
#
#
#
#         circle_65892d2e73527175c5a8b8070fbf2380.bindPopup(popup_19a11ca325f807d39b4719e1a2e7931b)
#         ;
#
#
#
#
#             var circle_943f49faf95f9946ee621959fe1d3e78 = L.circle(
#                 [33.9489, -118.3939],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3213.2000000000003, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_debefb064290ff473b0ee74cb95053c0);
#
#
#         var popup_ea76bdbcc6c810d44ab08a6a880c4eb0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ceb9ffb0923da56b250597b555d2e5fe = $(`&lt;div id=&quot;html_ceb9ffb0923da56b250597b555d2e5fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Area: Pacific&lt;br&gt;Age Group: Adult&lt;br&gt;Incidents: 40165&lt;/div&gt;`)[0];
#                 popup_ea76bdbcc6c810d44ab08a6a880c4eb0.setContent(html_ceb9ffb0923da56b250597b555d2e5fe);
#
#
#
#         circle_943f49faf95f9946ee621959fe1d3e78.bindPopup(popup_ea76bdbcc6c810d44ab08a6a880c4eb0)
#         ;
#
#
#
#
#             var circle_c9c5ee04b2514830e01fec21c0b1413d = L.circle(
#                 [34.2012, -118.416],
